# %%
# ETE CÍCERO DIAS
# DOCENTE : CLOVES
# ESTUDANTE : THIAGO AUGUSTO SANTANA PEREIRA
# TIPOS PRIMITIVOS DE DADOS EM PHYTON

print("Olá mundo!")

c = 'Thiago'
print(type(c))
# Out:
# Olá mundo!
# <class 'str'>
