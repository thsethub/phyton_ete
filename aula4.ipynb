# %% [markdown]
# <a href="https://colab.research.google.com/github/thsethub/phyton_ete/blob/main/aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ETE CÍCERO DIAS
# DOCENTE : CLOVES
# ESTUDANTE : THIAGO AUGUSTO SANTANA PEREIRA
# TIPOS PRIMITIVOS DE DADOS EM PHYTON

print("Olá mundo!")

t = 'Thiago'
print(type(t))
# Out:
# Olá mundo!
# <class 'str'>
